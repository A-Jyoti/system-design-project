# %%
import pandas as pd
df = pd.read_csv('dataset3.csv')
df.head()
# Out:
#    raw_rssi  rssi1_filtered  distance
# 0     -75.0          -75.00       2.0
# 1     -77.0          -76.00       2.0
# 2     -82.0          -78.00       2.0
# 3     -79.0          -78.25       2.0
# 4     -79.0          -78.40       2.0

# %%
#plot rss1_filtered vs distance
import matplotlib.pyplot as plt
plt.scatter(df['rssi1_filtered'], df['distance'])
plt.xlabel('RSSI1 Filtered')
plt.ylabel('Distance')
plt.title('RSSI1 Filtered vs Distance')
plt.show()
